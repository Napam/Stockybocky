# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib
from matplotlib import pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap
from IPython.core.display import HTML, display
import time
from typing import Callable, Union

# %%
from umap import UMAP
from sklearn.cluster import SpectralClustering, AgglomerativeClustering, KMeans, MeanShift, estimate_bandwidth
from sklearn.preprocessing import LabelEncoder, StandardScaler, RobustScaler, MinMaxScaler
from sklearn.manifold import LocallyLinearEmbedding, MDS, Isomap
from sklearn.decomposition import PCA, SparsePCA, NMF, KernelPCA
from sklearn.ensemble import IsolationForest

# %% [markdown]
# # Setup
# Setup environment such as themes, colors, seed

# %%
colors = ['lightpink','deepskyblue','orange', 'lime',
          'magenta','yellow','green','red','powderblue']

pypat_vanja = ListedColormap(colors)
matplotlib.style.use('default')
# matplotlib.style.use('dark_background')

# %%
# Fix seed
seed = 42069
np.random.seed(seed)

# %% [markdown]
# # Data analysis and preprocessing

# %%
df_raw = pd.read_csv('OSEBX_dataset.csv')
df = df_raw.copy()

# %%
def print_html(df: pd.DataFrame):
    '''Display give DataFrame as HTML table'''
    display(HTML(df.to_html()))

# %%
n_data, n_features = df.shape[0], df.shape[1]
print(f'There are in total {n_data} data points')
print(f'There are in total {n_features} features')
# Out:
# There are in total 246 data points
# There are in total 21 features

# %% [markdown]
# ### Inspecting the raw data
#
# Sampling 10 random samples without replacement to inspect the features and values.

# %%
print_html(df.sample(10, random_state=seed))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ticker</th>
#       <th>name</th>
#       <th>sector</th>
#       <th>last_</th>
#       <th>buy</th>
#       <th>sell</th>
#       <th>tradecount</th>
#       <th>info</th>
#       <th>marketcap</th>
#       <th>profit_today</th>
#       <th>profit_1wk</th>
#       <th>profit_1month</th>
#       <th>profit_ytd</th>
#       <th>profit_1yr</th>
#       <th>bookValue</th>
#       <th>enterpriseValue</th>
#       <th>trailingEps</th>
#       <th>forwardEps</th>
#       <th>priceToBook</th>
#       <th>beta</th>
#       <th>profitMargins</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>176</th>
#       <td>SALM</td>
#       <td>SalMar</td>
#       <td>Consumer staples</td>
#       <td>452.50</td>
#       <td>451.90</td>
#       <td>452.50</td>
#       <td>288</td>
#       <td>NaN</td>
#       <td>51097.59</td>
#       <td>-0.0059</td>
#       <td>-0.0107</td>
#       <td>-0.0040</td>
#       <td>0.0062</td>
#       <td>0.0937</td>
#       <td>73.818</td>
#       <td>5.461409e+10</td>
#       <td>26.429</td>
#       <td>28.73</td>
#       <td>6.125877</td>
#       <td>-0.313360</td>
#       <td>0.24618</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>AKVA</td>
#       <td>AKVA Group</td>
#       <td>Industrials</td>
#       <td>73.60</td>
#       <td>72.40</td>
#       <td>73.40</td>
#       <td>0</td>
#       <td>LP</td>
#       <td>2436.63</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>-0.0081</td>
#       <td>-0.0054</td>
#       <td>0.1082</td>
#       <td>32.930</td>
#       <td>3.536924e+09</td>
#       <td>3.560</td>
#       <td>5.73</td>
#       <td>2.235044</td>
#       <td>0.038866</td>
#       <td>0.03760</td>
#     </tr>
#     <tr>
#       <th>193</th>
#       <td>SOGN</td>
#       <td>Sogn Sparebank</td>
#       <td>Equity certificates</td>
#       <td>107.00</td>
#       <td>106.00</td>
#       <td>107.00</td>
#       <td>1</td>
#       <td>LP</td>
#       <td>67.68</td>
#       <td>0.0190</td>
#       <td>NaN</td>
#       <td>0.0000</td>
#       <td>0.0000</td>
#       <td>0.0396</td>
#       <td>1411.696</td>
#       <td>-7.429260e+08</td>
#       <td>7.366</td>
#       <td>NaN</td>
#       <td>0.075795</td>
#       <td>-0.083400</td>
#       <td>0.26904</td>
#     </tr>
#     <tr>
#       <th>173</th>
#       <td>ROM</td>
#       <td>RomReal</td>
#       <td>Real estate</td>
#       <td>2.26</td>
#       <td>2.02</td>
#       <td>2.22</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>93.38</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>-0.0887</td>
#       <td>-0.0174</td>
#       <td>0.0762</td>
#       <td>0.574</td>
#       <td>9.349119e+07</td>
#       <td>0.041</td>
#       <td>NaN</td>
#       <td>3.937282</td>
#       <td>-0.707578</td>
#       <td>0.00000</td>
#     </tr>
#     <tr>
#       <th>120</th>
#       <td>NAPA</td>
#       <td>Napatech</td>
#       <td>Information technology</td>
#       <td>4.69</td>
#       <td>4.54</td>
#       <td>4.69</td>
#       <td>4</td>
#       <td>NaN</td>
#       <td>389.54</td>
#       <td>0.0086</td>
#       <td>-0.0021</td>
#       <td>0.0353</td>
#       <td>0.0043</td>
#       <td>0.7033</td>
#       <td>0.397</td>
#       <td>1.436059e+08</td>
#       <td>-0.862</td>
#       <td>NaN</td>
#       <td>11.813602</td>
#       <td>-0.651012</td>
#       <td>-0.36110</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>ARCHER</td>
#       <td>Archer</td>
#       <td>Energy</td>
#       <td>3.06</td>
#       <td>3.01</td>
#       <td>3.06</td>
#       <td>19</td>
#       <td>NaN</td>
#       <td>452.68</td>
#       <td>0.0338</td>
#       <td>0.0552</td>
#       <td>-0.0585</td>
#       <td>-0.0377</td>
#       <td>-0.3964</td>
#       <td>0.656</td>
#       <td>1.090849e+09</td>
#       <td>-0.740</td>
#       <td>0.06</td>
#       <td>4.664634</td>
#       <td>3.076923</td>
#       <td>-0.12929</td>
#     </tr>
#     <tr>
#       <th>206</th>
#       <td>SBTE</td>
#       <td>Sparebanken Telemark</td>
#       <td>Equity certificates</td>
#       <td>133.00</td>
#       <td>133.50</td>
#       <td>135.00</td>
#       <td>6</td>
#       <td>NaN</td>
#       <td>1449.52</td>
#       <td>0.0153</td>
#       <td>0.0153</td>
#       <td>0.0231</td>
#       <td>0.0231</td>
#       <td>0.2021</td>
#       <td>313.526</td>
#       <td>7.386721e+09</td>
#       <td>15.338</td>
#       <td>NaN</td>
#       <td>0.424207</td>
#       <td>NaN</td>
#       <td>0.42772</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>FUNCOM</td>
#       <td>Funcom</td>
#       <td>Communication services</td>
#       <td>16.90</td>
#       <td>16.90</td>
#       <td>16.91</td>
#       <td>62</td>
#       <td>NaN</td>
#       <td>1306.15</td>
#       <td>0.0006</td>
#       <td>-0.0024</td>
#       <td>0.2852</td>
#       <td>0.2852</td>
#       <td>0.2930</td>
#       <td>0.582</td>
#       <td>1.293688e+09</td>
#       <td>0.013</td>
#       <td>NaN</td>
#       <td>29.037800</td>
#       <td>0.675303</td>
#       <td>0.04663</td>
#     </tr>
#     <tr>
#       <th>115</th>
#       <td>MEDI</td>
#       <td>Medistim</td>
#       <td>Health care</td>
#       <td>214.00</td>
#       <td>212.00</td>
#       <td>214.00</td>
#       <td>18</td>
#       <td>NaN</td>
#       <td>3894.55</td>
#       <td>0.0288</td>
#       <td>0.0190</td>
#       <td>0.1146</td>
#       <td>0.1146</td>
#       <td>2.2373</td>
#       <td>12.268</td>
#       <td>3.780276e+09</td>
#       <td>4.328</td>
#       <td>2.64</td>
#       <td>17.443756</td>
#       <td>-0.152226</td>
#       <td>0.21678</td>
#     </tr>
#     <tr>
#       <th>196</th>
#       <td>SBVG</td>
#       <td>SpareBank 1 BV</td>
#       <td>Equity certificates</td>
#       <td>41.20</td>
#       <td>41.20</td>
#       <td>41.50</td>
#       <td>0</td>
#       <td>LP</td>
#       <td>2595.91</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0457</td>
#       <td>0.0404</td>
#       <td>0.2049</td>
#       <td>81.579</td>
#       <td>1.021294e+10</td>
#       <td>4.591</td>
#       <td>4.12</td>
#       <td>0.505032</td>
#       <td>0.400809</td>
#       <td>0.42746</td>
#     </tr>
#   </tbody>
# </table>

# %%
print_html(df.describe())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>last_</th>
#       <th>buy</th>
#       <th>sell</th>
#       <th>tradecount</th>
#       <th>marketcap</th>
#       <th>profit_today</th>
#       <th>profit_1wk</th>
#       <th>profit_1month</th>
#       <th>profit_ytd</th>
#       <th>profit_1yr</th>
#       <th>bookValue</th>
#       <th>enterpriseValue</th>
#       <th>trailingEps</th>
#       <th>forwardEps</th>
#       <th>priceToBook</th>
#       <th>beta</th>
#       <th>profitMargins</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>246.000000</td>
#       <td>243.000000</td>
#       <td>242.000000</td>
#       <td>246.000000</td>
#       <td>246.000000</td>
#       <td>198.000000</td>
#       <td>198.000000</td>
#       <td>238.000000</td>
#       <td>240.000000</td>
#       <td>223.000000</td>
#       <td>228.000000</td>
#       <td>2.320000e+02</td>
#       <td>227.000000</td>
#       <td>150.000000</td>
#       <td>220.000000</td>
#       <td>205.000000</td>
#       <td>237.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>79.180163</td>
#       <td>79.766173</td>
#       <td>81.053099</td>
#       <td>141.666667</td>
#       <td>11649.612276</td>
#       <td>0.004882</td>
#       <td>0.017954</td>
#       <td>-0.006894</td>
#       <td>0.003994</td>
#       <td>0.139039</td>
#       <td>74.160759</td>
#       <td>1.998874e+10</td>
#       <td>3.426960</td>
#       <td>4.218200</td>
#       <td>6.242069</td>
#       <td>0.618544</td>
#       <td>0.073257</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>189.013683</td>
#       <td>190.453727</td>
#       <td>193.442311</td>
#       <td>385.846267</td>
#       <td>45220.255024</td>
#       <td>0.023839</td>
#       <td>0.069176</td>
#       <td>0.152840</td>
#       <td>0.168981</td>
#       <td>0.712706</td>
#       <td>197.073910</td>
#       <td>8.007807e+10</td>
#       <td>11.891779</td>
#       <td>7.194181</td>
#       <td>11.523394</td>
#       <td>1.153522</td>
#       <td>1.013403</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>0.040000</td>
#       <td>0.040000</td>
#       <td>0.040000</td>
#       <td>0.000000</td>
#       <td>1.300000</td>
#       <td>-0.106700</td>
#       <td>-0.176800</td>
#       <td>-0.421300</td>
#       <td>-0.409600</td>
#       <td>-0.998900</td>
#       <td>-40.465000</td>
#       <td>-7.429260e+08</td>
#       <td>-45.601000</td>
#       <td>-20.180000</td>
#       <td>0.006774</td>
#       <td>-11.622199</td>
#       <td>-2.338370</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>6.662500</td>
#       <td>7.385000</td>
#       <td>7.920000</td>
#       <td>1.250000</td>
#       <td>350.645000</td>
#       <td>-0.003650</td>
#       <td>-0.007400</td>
#       <td>-0.080375</td>
#       <td>-0.078350</td>
#       <td>-0.187100</td>
#       <td>1.873750</td>
#       <td>6.359169e+08</td>
#       <td>-0.343500</td>
#       <td>0.092500</td>
#       <td>0.984660</td>
#       <td>0.200000</td>
#       <td>-0.029130</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>29.500000</td>
#       <td>30.400000</td>
#       <td>31.445000</td>
#       <td>11.500000</td>
#       <td>1718.345000</td>
#       <td>0.001150</td>
#       <td>0.015400</td>
#       <td>-0.007600</td>
#       <td>-0.005350</td>
#       <td>0.059900</td>
#       <td>8.586000</td>
#       <td>2.873153e+09</td>
#       <td>0.222000</td>
#       <td>1.220000</td>
#       <td>3.100720</td>
#       <td>0.541700</td>
#       <td>0.030750</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>97.587500</td>
#       <td>98.425000</td>
#       <td>98.787500</td>
#       <td>81.500000</td>
#       <td>5694.257500</td>
#       <td>0.014825</td>
#       <td>0.038250</td>
#       <td>0.046150</td>
#       <td>0.068400</td>
#       <td>0.294000</td>
#       <td>34.508500</td>
#       <td>1.017529e+10</td>
#       <td>4.074000</td>
#       <td>6.852500</td>
#       <td>6.663188</td>
#       <td>0.987044</td>
#       <td>0.154280</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>2620.000000</td>
#       <td>2630.000000</td>
#       <td>2670.000000</td>
#       <td>3649.000000</td>
#       <td>569046.150000</td>
#       <td>0.186400</td>
#       <td>0.363600</td>
#       <td>0.786000</td>
#       <td>0.932600</td>
#       <td>6.025900</td>
#       <td>1411.696000</td>
#       <td>9.818277e+11</td>
#       <td>90.434000</td>
#       <td>31.330000</td>
#       <td>124.999990</td>
#       <td>4.485829</td>
#       <td>12.562961</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Encode string labels to numerical
sectorencoder = LabelEncoder()
infoencoder = LabelEncoder()
df['sector'] = sectorencoder.fit_transform(df['sector'])
df['info'].fillna('nLP', inplace=True)
df['info'] = infoencoder.fit_transform(df['info'])

# %%
print(df.sample(10, random_state=seed)[['sector','info']])
# Out:
#      sector  info
# 176       2     1
# 12        7     0
# 193       4     0
# 173      10     1
# 120       8     1
# 16        3     1
# 206       4     1
# 69        0     1
# 115       6     1
# 196       4     0

# %%
print_html(df.head())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ticker</th>
#       <th>name</th>
#       <th>sector</th>
#       <th>last_</th>
#       <th>buy</th>
#       <th>sell</th>
#       <th>tradecount</th>
#       <th>info</th>
#       <th>marketcap</th>
#       <th>profit_today</th>
#       <th>profit_1wk</th>
#       <th>profit_1month</th>
#       <th>profit_ytd</th>
#       <th>profit_1yr</th>
#       <th>bookValue</th>
#       <th>enterpriseValue</th>
#       <th>trailingEps</th>
#       <th>forwardEps</th>
#       <th>priceToBook</th>
#       <th>beta</th>
#       <th>profitMargins</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2020</td>
#       <td>2020 Bulkers</td>
#       <td>7</td>
#       <td>77.80</td>
#       <td>75.40</td>
#       <td>77.40</td>
#       <td>3</td>
#       <td>1</td>
#       <td>1724.90</td>
#       <td>0.0026</td>
#       <td>-0.0051</td>
#       <td>-0.0698</td>
#       <td>-0.1081</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.00000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>FIVEPG</td>
#       <td>5th Planet Games</td>
#       <td>0</td>
#       <td>0.38</td>
#       <td>0.37</td>
#       <td>0.38</td>
#       <td>11</td>
#       <td>0</td>
#       <td>20.20</td>
#       <td>-0.0131</td>
#       <td>-0.1048</td>
#       <td>-0.0157</td>
#       <td>0.0190</td>
#       <td>-0.7314</td>
#       <td>0.174</td>
#       <td>2.078832e+07</td>
#       <td>-0.118</td>
#       <td>NaN</td>
#       <td>2.160919</td>
#       <td>1.302454</td>
#       <td>0.00000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>AASB-ME</td>
#       <td>Aasen Sparebank</td>
#       <td>4</td>
#       <td>140.00</td>
#       <td>145.00</td>
#       <td>150.00</td>
#       <td>0</td>
#       <td>0</td>
#       <td>141.95</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0853</td>
#       <td>0.2960</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.239307</td>
#       <td>0.40017</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ASC</td>
#       <td>ABG Sundal Collier Holding</td>
#       <td>5</td>
#       <td>3.99</td>
#       <td>3.99</td>
#       <td>4.01</td>
#       <td>16</td>
#       <td>1</td>
#       <td>1822.11</td>
#       <td>-0.0062</td>
#       <td>0.0000</td>
#       <td>0.0310</td>
#       <td>0.0000</td>
#       <td>-0.0126</td>
#       <td>1.442</td>
#       <td>1.550584e+09</td>
#       <td>0.305</td>
#       <td>0.43</td>
#       <td>2.766990</td>
#       <td>0.827530</td>
#       <td>0.13757</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>ADE</td>
#       <td>Adevinta</td>
#       <td>0</td>
#       <td>121.00</td>
#       <td>120.40</td>
#       <td>121.20</td>
#       <td>252</td>
#       <td>1</td>
#       <td>82878.77</td>
#       <td>0.0000</td>
#       <td>0.0881</td>
#       <td>0.1183</td>
#       <td>0.1635</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>8.241889e+10</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.04859</td>
#     </tr>
#   </tbody>
# </table>

# %%
cplot = sns.countplot(df_raw.sector)
cplot.set_xticklabels(cplot.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# # Bivariate Statistics

# %%
# sns.pairplot(df, height=1)
# plt.show()

# %%
covmat = df.cov()
cormat = df.corr()

fig, axes = plt.subplots(1, 2, figsize=(8,3.5))
sns.heatmap(covmat, ax=axes[0], center=0)
sns.heatmap(cormat, ax=axes[1], center=0)
axes[0].set_title('Covariance matrix')
axes[1].set_title('Correlation matrix')
fig.tight_layout(rect=(0,0,1,1))
plt.show()

# %% [markdown]
# From correlation matrix, find the top 3 correlated features

# %%
abscormat = cormat.abs()
triabscormat = abscormat.where(np.triu(np.ones(abscormat.shape), k=1).astype(bool)).stack()
print(list(triabscormat.sort_values(ascending=False).index[:3]))
# Out:
# [('last_', 'buy'), ('buy', 'sell'), ('last_', 'sell')]

# %%
viz_features = np.unique(list(triabscormat.sort_values(ascending=False).index[0:3]))
print(viz_features)
# Out:
# ['buy' 'last_' 'sell']

# %%
print_html(df.sample(10))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ticker</th>
#       <th>name</th>
#       <th>sector</th>
#       <th>last_</th>
#       <th>buy</th>
#       <th>sell</th>
#       <th>tradecount</th>
#       <th>info</th>
#       <th>marketcap</th>
#       <th>profit_today</th>
#       <th>profit_1wk</th>
#       <th>profit_1month</th>
#       <th>profit_ytd</th>
#       <th>profit_1yr</th>
#       <th>bookValue</th>
#       <th>enterpriseValue</th>
#       <th>trailingEps</th>
#       <th>forwardEps</th>
#       <th>priceToBook</th>
#       <th>beta</th>
#       <th>profitMargins</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>176</th>
#       <td>SALM</td>
#       <td>SalMar</td>
#       <td>2</td>
#       <td>452.50</td>
#       <td>451.90</td>
#       <td>452.50</td>
#       <td>288</td>
#       <td>1</td>
#       <td>51097.59</td>
#       <td>-0.0059</td>
#       <td>-0.0107</td>
#       <td>-0.0040</td>
#       <td>0.0062</td>
#       <td>0.0937</td>
#       <td>73.818</td>
#       <td>5.461409e+10</td>
#       <td>26.429</td>
#       <td>28.73</td>
#       <td>6.125877</td>
#       <td>-0.313360</td>
#       <td>0.24618</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>AKVA</td>
#       <td>AKVA Group</td>
#       <td>7</td>
#       <td>73.60</td>
#       <td>72.40</td>
#       <td>73.40</td>
#       <td>0</td>
#       <td>0</td>
#       <td>2436.63</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>-0.0081</td>
#       <td>-0.0054</td>
#       <td>0.1082</td>
#       <td>32.930</td>
#       <td>3.536924e+09</td>
#       <td>3.560</td>
#       <td>5.73</td>
#       <td>2.235044</td>
#       <td>0.038866</td>
#       <td>0.03760</td>
#     </tr>
#     <tr>
#       <th>193</th>
#       <td>SOGN</td>
#       <td>Sogn Sparebank</td>
#       <td>4</td>
#       <td>107.00</td>
#       <td>106.00</td>
#       <td>107.00</td>
#       <td>1</td>
#       <td>0</td>
#       <td>67.68</td>
#       <td>0.0190</td>
#       <td>NaN</td>
#       <td>0.0000</td>
#       <td>0.0000</td>
#       <td>0.0396</td>
#       <td>1411.696</td>
#       <td>-7.429260e+08</td>
#       <td>7.366</td>
#       <td>NaN</td>
#       <td>0.075795</td>
#       <td>-0.083400</td>
#       <td>0.26904</td>
#     </tr>
#     <tr>
#       <th>173</th>
#       <td>ROM</td>
#       <td>RomReal</td>
#       <td>10</td>
#       <td>2.26</td>
#       <td>2.02</td>
#       <td>2.22</td>
#       <td>0</td>
#       <td>1</td>
#       <td>93.38</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>-0.0887</td>
#       <td>-0.0174</td>
#       <td>0.0762</td>
#       <td>0.574</td>
#       <td>9.349119e+07</td>
#       <td>0.041</td>
#       <td>NaN</td>
#       <td>3.937282</td>
#       <td>-0.707578</td>
#       <td>0.00000</td>
#     </tr>
#     <tr>
#       <th>120</th>
#       <td>NAPA</td>
#       <td>Napatech</td>
#       <td>8</td>
#       <td>4.69</td>
#       <td>4.54</td>
#       <td>4.69</td>
#       <td>4</td>
#       <td>1</td>
#       <td>389.54</td>
#       <td>0.0086</td>
#       <td>-0.0021</td>
#       <td>0.0353</td>
#       <td>0.0043</td>
#       <td>0.7033</td>
#       <td>0.397</td>
#       <td>1.436059e+08</td>
#       <td>-0.862</td>
#       <td>NaN</td>
#       <td>11.813602</td>
#       <td>-0.651012</td>
#       <td>-0.36110</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>ARCHER</td>
#       <td>Archer</td>
#       <td>3</td>
#       <td>3.06</td>
#       <td>3.01</td>
#       <td>3.06</td>
#       <td>19</td>
#       <td>1</td>
#       <td>452.68</td>
#       <td>0.0338</td>
#       <td>0.0552</td>
#       <td>-0.0585</td>
#       <td>-0.0377</td>
#       <td>-0.3964</td>
#       <td>0.656</td>
#       <td>1.090849e+09</td>
#       <td>-0.740</td>
#       <td>0.06</td>
#       <td>4.664634</td>
#       <td>3.076923</td>
#       <td>-0.12929</td>
#     </tr>
#     <tr>
#       <th>206</th>
#       <td>SBTE</td>
#       <td>Sparebanken Telemark</td>
#       <td>4</td>
#       <td>133.00</td>
#       <td>133.50</td>
#       <td>135.00</td>
#       <td>6</td>
#       <td>1</td>
#       <td>1449.52</td>
#       <td>0.0153</td>
#       <td>0.0153</td>
#       <td>0.0231</td>
#       <td>0.0231</td>
#       <td>0.2021</td>
#       <td>313.526</td>
#       <td>7.386721e+09</td>
#       <td>15.338</td>
#       <td>NaN</td>
#       <td>0.424207</td>
#       <td>NaN</td>
#       <td>0.42772</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>FUNCOM</td>
#       <td>Funcom</td>
#       <td>0</td>
#       <td>16.90</td>
#       <td>16.90</td>
#       <td>16.91</td>
#       <td>62</td>
#       <td>1</td>
#       <td>1306.15</td>
#       <td>0.0006</td>
#       <td>-0.0024</td>
#       <td>0.2852</td>
#       <td>0.2852</td>
#       <td>0.2930</td>
#       <td>0.582</td>
#       <td>1.293688e+09</td>
#       <td>0.013</td>
#       <td>NaN</td>
#       <td>29.037800</td>
#       <td>0.675303</td>
#       <td>0.04663</td>
#     </tr>
#     <tr>
#       <th>115</th>
#       <td>MEDI</td>
#       <td>Medistim</td>
#       <td>6</td>
#       <td>214.00</td>
#       <td>212.00</td>
#       <td>214.00</td>
#       <td>18</td>
#       <td>1</td>
#       <td>3894.55</td>
#       <td>0.0288</td>
#       <td>0.0190</td>
#       <td>0.1146</td>
#       <td>0.1146</td>
#       <td>2.2373</td>
#       <td>12.268</td>
#       <td>3.780276e+09</td>
#       <td>4.328</td>
#       <td>2.64</td>
#       <td>17.443756</td>
#       <td>-0.152226</td>
#       <td>0.21678</td>
#     </tr>
#     <tr>
#       <th>196</th>
#       <td>SBVG</td>
#       <td>SpareBank 1 BV</td>
#       <td>4</td>
#       <td>41.20</td>
#       <td>41.20</td>
#       <td>41.50</td>
#       <td>0</td>
#       <td>0</td>
#       <td>2595.91</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0457</td>
#       <td>0.0404</td>
#       <td>0.2049</td>
#       <td>81.579</td>
#       <td>1.021294e+10</td>
#       <td>4.591</td>
#       <td>4.12</td>
#       <td>0.505032</td>
#       <td>0.400809</td>
#       <td>0.42746</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Look here to select which features to exclude

# %%
# Separate data and labels for conventional purposes
dfx = df.drop(columns=['name', 'ticker', 'sector','info']).fillna(0)
X, y = dfx.values, df.sector.values.flatten()

# print_html(dfx)

# %%
print(X)
# Out:
# [[ 7.7800000e+01  7.5400000e+01  7.7400000e+01 ...  0.0000000e+00
#    0.0000000e+00  0.0000000e+00]
#  [ 3.8000000e-01  3.7000000e-01  3.8000000e-01 ...  2.1609194e+00
#    1.3024540e+00  0.0000000e+00]
#  [ 1.4000000e+02  1.4500000e+02  1.5000000e+02 ...  0.0000000e+00
#    2.3930700e-01  4.0016997e-01]
#  ...
#  [ 3.1500000e+01  3.0500000e+01  3.1500000e+01 ...  6.6065435e+00
#    8.9554600e-01 -1.0360000e-02]
#  [ 1.8000000e-01  1.8000000e-01  1.8000000e-01 ...  0.0000000e+00
#    1.4694830e+00 -1.6545400e+00]
#  [ 5.9500000e+00  5.7000000e+00  5.9500000e+00 ...  1.1852590e+00
#    0.0000000e+00  0.0000000e+00]]

# %%
minmaxscaler = MinMaxScaler().fit(X)
# standardscaler = StandardScaler().fit(X)
# robustscaler = RobustScaler().fit(X)

X_minmax = minmaxscaler.transform(X)
# X_standard = standardscaler.transform(X)
# X_robust = robustscaler.transform(X)

# %%
def scatter2d3d(df, theta=(45,45), aspect_equal: bool = False, figsize: tuple = (12,4), *args, **kwargs) -> tuple:
    '''
    Given a dataframe with at least three columns, scatterplot the data on a 3D axes object as well as 
    all the 2D projections of the axes. The columns names of the dataframe will be used as axes names.  
    '''
    X = df.values
    fnames = df.columns 

    # Create figure and axes
    fig = plt.figure(figsize=figsize)    
    axes = [fig.add_subplot(141, projection='3d'), fig.add_subplot(142), fig.add_subplot(143), fig.add_subplot(144)]  

    axes[0].scatter(*X[:,[0,1,2]].T, *args, **kwargs)
    axes[1].scatter(*X[:,[0,1]].T, *args, **kwargs)
    axes[2].scatter(*X[:,[1,2]].T, *args, **kwargs)
    axes[3].scatter(*X[:,[0,2]].T, *args, **kwargs)
    
    axes[0].view_init(*theta)
    plt.setp(axes[0], xlabel=fnames[0], ylabel=fnames[1], zlabel=fnames[2])
    plt.setp(axes[1], xlabel=fnames[0], ylabel=fnames[1])
    plt.setp(axes[2], xlabel=fnames[1], ylabel=fnames[2])
    plt.setp(axes[3], xlabel=fnames[0], ylabel=fnames[2])
    
    [ax.grid() for ax in axes]
    if aspect_equal:
        [ax.set_aspect('equal') for ax in axes]

    fig.tight_layout()
    return fig, axes

# %%
scatter2d3d(df[viz_features], (40,20), c=y, figsize=(11,2.7), edgecolor='dimgrey', cmap='Set1', alpha=0.9)
plt.show()

# %%
def name(obj) -> str:
    '''Get string name of obj, works for functions and instances'''
    return obj.__name__ if isinstance(obj, Callable) else obj.__class__.__name__

# %%
def get_visualizations(X: np.ndarray, visualizers: list, show: bool=False) -> dict:
    '''
    Takes in X and returns a list of all visualizeres from Sklearn-API visualization
    (e.g. UMAP) algorithms. Visualizers should be allocated objects. Returns a dicitonary
    with the names of the visualizers and the values are the result from said visualizer.
    '''
    transforms = dict()
    for i, viz in enumerate(visualizers):
        algoname = name(viz)
        t0 = time.time()
        print(f'Running {algoname}', end='')
        temp = viz.fit_transform(X)
        print(f'\r{algoname} transformed in {time.time()-t0:.2f} seconds')
        
        # If same type of function is used multiple times
        if algoname in transforms:
            transforms[algoname+f'{i}'] = temp
        else:
            transforms[algoname] = temp
        
    print()
    return transforms

# %%
def show_visualizations(vizzes: dict, y: np.ndarray, title=None, **kwargs) -> None:
    '''
    Takes in a dictionary where keys are name of an algroithm, e.g UMAP and the corresponding
    value is 2D plot data.
    '''
    n_viz = len(vizzes)
    
    fig, axes = plt.subplots(1, n_viz, figsize=(3*n_viz, 0.6*n_viz))
    
    for ax, name, X in zip(axes, vizzes.keys(), vizzes.values()):
        ax.scatter(*X.T, c=y, **kwargs)
        ax.set_title(name)
    
    if title:
        fig.suptitle(title)
        fig.tight_layout(rect=(0,0,1,0.90))
    else:
        fig.tight_layout()

    plt.show()

# %%
common_viz_kwargs = dict(n_components=2, random_state=seed)
vizgroup1 = [UMAP(n_epochs=500, n_neighbors=10, **common_viz_kwargs), MDS(n_init=4, n_jobs=-1, **common_viz_kwargs), PCA(**common_viz_kwargs), LocallyLinearEmbedding(n_neighbors=10, **common_viz_kwargs), Isomap(n_neighbors=10, n_components=2)]
vizgroup2 = [UMAP(n_epochs=500, n_neighbors=20, **common_viz_kwargs), MDS(n_init=8, n_jobs=-1, **common_viz_kwargs), KernelPCA(kernel='rbf', **common_viz_kwargs), LocallyLinearEmbedding(n_neighbors=20, **common_viz_kwargs), Isomap(n_neighbors=20, n_components=2)]
vizgroup3 = [UMAP(n_epochs=500, n_neighbors=30, **common_viz_kwargs), MDS(n_init=12, n_jobs=-1, **common_viz_kwargs), SparsePCA(normalize_components=True, **common_viz_kwargs), LocallyLinearEmbedding(n_neighbors=30, **common_viz_kwargs), Isomap(n_neighbors=30, n_components=2)]

# %%
vizzes1 = get_visualizations(X_minmax, vizgroup1)
vizzes2 = get_visualizations(X_minmax, vizgroup2)
vizzes3 = get_visualizations(X_minmax, vizgroup3)
# Out:
# UMAP transformed in 9.07 seconds
# MDS transformed in 4.69 seconds
# PCA transformed in 0.01 seconds
# LocallyLinearEmbedding transformed in 0.10 seconds
# Isomap transformed in 0.10 seconds
#
# UMAP transformed in 1.06 seconds
# MDS transformed in 4.75 seconds
# KernelPCA transformed in 0.01 seconds
# LocallyLinearEmbedding transformed in 0.10 seconds
# Isomap transformed in 0.06 seconds
#
# UMAP transformed in 0.77 seconds
# MDS transformed in 4.75 seconds
# SparsePCA transformed in 0.07 seconds
# LocallyLinearEmbedding transformed in 0.11 seconds
# Isomap transformed in 0.09 seconds

# %%
show_visualizations(vizzes1, y, cmap='Set1', edgecolor='silver', alpha=0.8)
show_visualizations(vizzes2, y, cmap='Set1', edgecolor='silver', alpha=0.8)
show_visualizations(vizzes3, y, cmap='Set1', edgecolor='silver', alpha=0.8)

# %%
scatter2d3d(pd.DataFrame(PCA(3).fit_transform(X_minmax), columns=['PC1', 'PC2', 'PC3']), (60,20), 
            c=y, figsize=(10,2.5), edgecolor='silver', cmap='Set1', alpha=0.8)
plt.show()

# %%
import altair as alt

# %%
df_altair = pd.DataFrame()
df_altair['X_mds'], df_altair['Y_mds'] = vizzes1['MDS'].T[0], vizzes1['MDS'].T[1]
df_altair['X_pca'], df_altair['Y_pca'] = vizzes1['PCA'].T[0], vizzes1['PCA'].T[1]
df_altair['X_lle'], df_altair['Y_lle'] = vizzes3['LocallyLinearEmbedding'].T[0], vizzes3['LocallyLinearEmbedding'].T[1]
df_altair['X_iso'], df_altair['Y_iso'] = vizzes3['Isomap'].T[0], vizzes3['Isomap'].T[1]
df_altair['ticker'] = df.ticker
df_altair['sector'] = df_raw.sector
df_altair['mcap'] = np.sqrt(df_raw.marketcap.astype(float))

# %%
input_dropdown = alt.binding_select(options=list(np.unique(df_altair.sector.values)))
interval = alt.selection_interval(encodings=['x', 'y'])
selection = alt.selection_single(fields=['sector'], bind=input_dropdown, name='LOL')
color = alt.condition(selection,
                    alt.Color('sector:N', legend=None),
                    alt.value('lightgray'))

chart2 = alt.Chart(df_altair).mark_point().encode(
    color=color,
    tooltip='ticker:N',
    size='mcap'
).add_selection(
    selection
).add_selection(
    interval
)

(chart2.encode(x='X_mds', y='Y_mds') | chart2.encode(x='X_pca', y='Y_pca')) &\
(chart2.encode(x='X_lle', y='Y_lle') | chart2.encode(x='X_iso', y='Y_iso'))
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
interval = alt.selection_interval(encodings=['x', 'y'])

chart = alt.Chart(df_altair).mark_point().encode(
    color=alt.condition(interval, 'sector', alt.value('lightgray')),
    tooltip=['ticker'],
    size='mcap',
).properties(selection=interval)

(chart.encode(x='X_mds', y='Y_mds') | chart.encode(x='X_pca', y='Y_pca')) &\
(chart.encode(x='X_lle', y='Y_lle') | chart.encode(x='X_iso', y='Y_iso'))
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
iforest = IsolationForest(behaviour='new', contamination='auto', n_estimators=256, n_jobs=-1, random_state=seed, bootstrap=True, max_features=6)

# %%
iforest.fit(df_altair[df_altair.columns[:8]].values)
# iforest.fit(X_minmax)
# Out:
# IsolationForest(behaviour='new', bootstrap=True, contamination='auto',
#                 max_features=6, max_samples='auto', n_estimators=256, n_jobs=-1,
#                 random_state=42069, verbose=0, warm_start=False)

# %%
scores = iforest.score_samples(df_altair[df_altair.columns[:8]].values)
# scores = iforest.score_samples(X_minmax)

# %%
df_altair_scored = df_altair.copy()
df_altair_scored['scores'] = -scores
print_html(df_altair_scored.sample(5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X_mds</th>
#       <th>Y_mds</th>
#       <th>X_pca</th>
#       <th>Y_pca</th>
#       <th>X_lle</th>
#       <th>Y_lle</th>
#       <th>X_iso</th>
#       <th>Y_iso</th>
#       <th>ticker</th>
#       <th>sector</th>
#       <th>mcap</th>
#       <th>scores</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>86</th>
#       <td>-0.092639</td>
#       <td>-0.531538</td>
#       <td>-0.231509</td>
#       <td>0.042191</td>
#       <td>-0.086361</td>
#       <td>0.018762</td>
#       <td>-0.364186</td>
#       <td>-0.219803</td>
#       <td>HBC</td>
#       <td>Health care</td>
#       <td>50.476430</td>
#       <td>0.519775</td>
#     </tr>
#     <tr>
#       <th>101</th>
#       <td>-0.224389</td>
#       <td>-0.097584</td>
#       <td>0.048989</td>
#       <td>-0.101966</td>
#       <td>-0.061293</td>
#       <td>-0.072449</td>
#       <td>-0.135390</td>
#       <td>0.121743</td>
#       <td>KAHOOT-ME</td>
#       <td>Communication services</td>
#       <td>97.036488</td>
#       <td>0.444325</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>-0.043347</td>
#       <td>-0.071708</td>
#       <td>-0.038739</td>
#       <td>-0.074232</td>
#       <td>-0.028710</td>
#       <td>-0.000755</td>
#       <td>-0.018837</td>
#       <td>0.007752</td>
#       <td>ATLA NOK</td>
#       <td>Energy</td>
#       <td>5.438750</td>
#       <td>0.379358</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>-0.251996</td>
#       <td>-0.433802</td>
#       <td>-0.101267</td>
#       <td>-0.000454</td>
#       <td>-0.021987</td>
#       <td>-0.006121</td>
#       <td>-0.275983</td>
#       <td>-0.074219</td>
#       <td>AVANCE</td>
#       <td>Energy</td>
#       <td>55.991696</td>
#       <td>0.474644</td>
#     </tr>
#     <tr>
#       <th>165</th>
#       <td>-0.298569</td>
#       <td>-0.268094</td>
#       <td>0.016914</td>
#       <td>-0.128132</td>
#       <td>-0.087397</td>
#       <td>0.024193</td>
#       <td>-0.234468</td>
#       <td>0.124022</td>
#       <td>PRS</td>
#       <td>Energy</td>
#       <td>14.305943</td>
#       <td>0.495596</td>
#     </tr>
#   </tbody>
# </table>

# %%
top20 = df_altair_scored.sort_values(by='scores', ascending=False).head(20)

# %%
print_html(top20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X_mds</th>
#       <th>Y_mds</th>
#       <th>X_pca</th>
#       <th>Y_pca</th>
#       <th>X_lle</th>
#       <th>Y_lle</th>
#       <th>X_iso</th>
#       <th>Y_iso</th>
#       <th>ticker</th>
#       <th>sector</th>
#       <th>mcap</th>
#       <th>scores</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18</th>
#       <td>-0.891679</td>
#       <td>1.710236</td>
#       <td>0.671329</td>
#       <td>1.371171</td>
#       <td>0.319685</td>
#       <td>0.154397</td>
#       <td>1.777393</td>
#       <td>-0.359403</td>
#       <td>AFK</td>
#       <td>Industrials</td>
#       <td>75.738233</td>
#       <td>0.793420</td>
#     </tr>
#     <tr>
#       <th>230</th>
#       <td>-0.875974</td>
#       <td>0.508905</td>
#       <td>0.783086</td>
#       <td>-0.496264</td>
#       <td>0.224579</td>
#       <td>-0.175650</td>
#       <td>-0.184802</td>
#       <td>1.023688</td>
#       <td>ULTIMO</td>
#       <td>Health care</td>
#       <td>44.787833</td>
#       <td>0.726591</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>-0.968150</td>
#       <td>0.322796</td>
#       <td>0.850834</td>
#       <td>-0.534769</td>
#       <td>0.163201</td>
#       <td>-0.198721</td>
#       <td>-0.196777</td>
#       <td>1.087459</td>
#       <td>BIOTEC</td>
#       <td>Health care</td>
#       <td>21.064425</td>
#       <td>0.725463</td>
#     </tr>
#     <tr>
#       <th>112</th>
#       <td>0.358522</td>
#       <td>0.783628</td>
#       <td>0.273750</td>
#       <td>0.480031</td>
#       <td>0.188627</td>
#       <td>0.231373</td>
#       <td>0.747270</td>
#       <td>-0.318568</td>
#       <td>LSTSB-ME</td>
#       <td>Equity certificates</td>
#       <td>11.401754</td>
#       <td>0.686354</td>
#     </tr>
#     <tr>
#       <th>164</th>
#       <td>-0.800876</td>
#       <td>0.177284</td>
#       <td>0.635024</td>
#       <td>-0.389455</td>
#       <td>0.086872</td>
#       <td>-0.142639</td>
#       <td>-0.143260</td>
#       <td>0.823890</td>
#       <td>PLT</td>
#       <td>Information technology</td>
#       <td>23.579440</td>
#       <td>0.659745</td>
#     </tr>
#     <tr>
#       <th>171</th>
#       <td>-0.850410</td>
#       <td>-0.001279</td>
#       <td>0.513684</td>
#       <td>-0.357101</td>
#       <td>-0.031221</td>
#       <td>-0.146985</td>
#       <td>-0.288497</td>
#       <td>0.676211</td>
#       <td>REC</td>
#       <td>Information technology</td>
#       <td>35.406073</td>
#       <td>0.657971</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>0.334896</td>
#       <td>-0.469068</td>
#       <td>-0.515396</td>
#       <td>0.174578</td>
#       <td>-0.116018</td>
#       <td>0.112374</td>
#       <td>-0.407609</td>
#       <td>-0.495412</td>
#       <td>BDRILL</td>
#       <td>Energy</td>
#       <td>70.405255</td>
#       <td>0.656819</td>
#     </tr>
#     <tr>
#       <th>204</th>
#       <td>0.107748</td>
#       <td>0.755235</td>
#       <td>0.363074</td>
#       <td>0.576449</td>
#       <td>0.176574</td>
#       <td>0.130715</td>
#       <td>0.804369</td>
#       <td>-0.095233</td>
#       <td>MORG</td>
#       <td>Equity certificates</td>
#       <td>57.320154</td>
#       <td>0.653183</td>
#     </tr>
#     <tr>
#       <th>193</th>
#       <td>0.136001</td>
#       <td>0.930107</td>
#       <td>0.250859</td>
#       <td>0.537018</td>
#       <td>0.113640</td>
#       <td>0.162294</td>
#       <td>0.816534</td>
#       <td>-0.244392</td>
#       <td>SOGN</td>
#       <td>Equity certificates</td>
#       <td>8.226786</td>
#       <td>0.641060</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>-0.593058</td>
#       <td>0.265833</td>
#       <td>0.463562</td>
#       <td>-0.294369</td>
#       <td>0.137061</td>
#       <td>-0.172850</td>
#       <td>-0.056649</td>
#       <td>0.613546</td>
#       <td>CRAYON</td>
#       <td>Information technology</td>
#       <td>74.103981</td>
#       <td>0.633211</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>-0.554272</td>
#       <td>0.408633</td>
#       <td>0.423557</td>
#       <td>-0.328977</td>
#       <td>0.140744</td>
#       <td>-0.119780</td>
#       <td>-0.114219</td>
#       <td>0.605834</td>
#       <td>ASETEK</td>
#       <td>Information technology</td>
#       <td>31.271393</td>
#       <td>0.624630</td>
#     </tr>
#     <tr>
#       <th>234</th>
#       <td>-0.812799</td>
#       <td>-0.336334</td>
#       <td>0.264283</td>
#       <td>-0.182607</td>
#       <td>0.103211</td>
#       <td>-0.154409</td>
#       <td>-0.243181</td>
#       <td>0.376437</td>
#       <td>VOW</td>
#       <td>Industrials</td>
#       <td>60.633654</td>
#       <td>0.622582</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>0.600020</td>
#       <td>0.345998</td>
#       <td>0.134822</td>
#       <td>-0.192069</td>
#       <td>-0.058820</td>
#       <td>-0.273264</td>
#       <td>-0.236752</td>
#       <td>0.207926</td>
#       <td>EMGS</td>
#       <td>Energy</td>
#       <td>17.089763</td>
#       <td>0.619468</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>0.968047</td>
#       <td>0.601824</td>
#       <td>0.227569</td>
#       <td>0.220467</td>
#       <td>0.099728</td>
#       <td>-0.091563</td>
#       <td>0.302618</td>
#       <td>0.169085</td>
#       <td>DNB</td>
#       <td>Financials</td>
#       <td>518.758335</td>
#       <td>0.608976</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>1.051311</td>
#       <td>0.466733</td>
#       <td>0.021740</td>
#       <td>0.088459</td>
#       <td>0.072702</td>
#       <td>-0.157210</td>
#       <td>0.071134</td>
#       <td>0.176943</td>
#       <td>EQNR</td>
#       <td>Energy</td>
#       <td>754.351476</td>
#       <td>0.602952</td>
#     </tr>
#     <tr>
#       <th>142</th>
#       <td>0.089297</td>
#       <td>-0.566998</td>
#       <td>-0.340576</td>
#       <td>0.094486</td>
#       <td>-0.029622</td>
#       <td>0.175896</td>
#       <td>-0.368517</td>
#       <td>-0.361582</td>
#       <td>OBSERV</td>
#       <td>Health care</td>
#       <td>11.554220</td>
#       <td>0.601436</td>
#     </tr>
#     <tr>
#       <th>89</th>
#       <td>-0.071271</td>
#       <td>0.662663</td>
#       <td>0.378461</td>
#       <td>0.372938</td>
#       <td>0.125597</td>
#       <td>0.100328</td>
#       <td>0.677767</td>
#       <td>-0.055096</td>
#       <td>HSPG</td>
#       <td>Equity certificates</td>
#       <td>9.778548</td>
#       <td>0.598216</td>
#     </tr>
#     <tr>
#       <th>157</th>
#       <td>0.523498</td>
#       <td>0.206308</td>
#       <td>-0.027419</td>
#       <td>0.186273</td>
#       <td>0.081022</td>
#       <td>0.153414</td>
#       <td>0.276568</td>
#       <td>-0.274513</td>
#       <td>PNOR</td>
#       <td>Energy</td>
#       <td>30.225155</td>
#       <td>0.592354</td>
#     </tr>
#     <tr>
#       <th>198</th>
#       <td>0.177557</td>
#       <td>0.625175</td>
#       <td>0.197362</td>
#       <td>0.471266</td>
#       <td>0.104942</td>
#       <td>0.140771</td>
#       <td>0.666460</td>
#       <td>-0.193966</td>
#       <td>SNOR</td>
#       <td>Equity certificates</td>
#       <td>15.876083</td>
#       <td>0.589616</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>-0.115310</td>
#       <td>-0.835065</td>
#       <td>-0.244718</td>
#       <td>0.071702</td>
#       <td>-0.011677</td>
#       <td>0.047216</td>
#       <td>-0.416546</td>
#       <td>-0.384536</td>
#       <td>BSP-ME</td>
#       <td>Consumer discretionary</td>
#       <td>6.209670</td>
#       <td>0.585182</td>
#     </tr>
#   </tbody>
# </table>

# %%
print_html(df_raw.loc[df_raw['ticker'].isin(top20.ticker)].loc[top20.index])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ticker</th>
#       <th>name</th>
#       <th>sector</th>
#       <th>last_</th>
#       <th>buy</th>
#       <th>sell</th>
#       <th>tradecount</th>
#       <th>info</th>
#       <th>marketcap</th>
#       <th>profit_today</th>
#       <th>profit_1wk</th>
#       <th>profit_1month</th>
#       <th>profit_ytd</th>
#       <th>profit_1yr</th>
#       <th>bookValue</th>
#       <th>enterpriseValue</th>
#       <th>trailingEps</th>
#       <th>forwardEps</th>
#       <th>priceToBook</th>
#       <th>beta</th>
#       <th>profitMargins</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18</th>
#       <td>AFK</td>
#       <td>Arendals Fossekompani</td>
#       <td>Industrials</td>
#       <td>2620.00</td>
#       <td>2630.00</td>
#       <td>2670.00</td>
#       <td>2</td>
#       <td>NaN</td>
#       <td>5736.28</td>
#       <td>0.0000</td>
#       <td>0.0000</td>
#       <td>0.0038</td>
#       <td>-0.0038</td>
#       <td>-0.2236</td>
#       <td>1387.583</td>
#       <td>5.471961e+09</td>
#       <td>22.268</td>
#       <td>NaN</td>
#       <td>1.888175</td>
#       <td>0.223481</td>
#       <td>0.00994</td>
#     </tr>
#     <tr>
#       <th>230</th>
#       <td>ULTIMO</td>
#       <td>Ultimovacs</td>
#       <td>Health care</td>
#       <td>72.00</td>
#       <td>71.80</td>
#       <td>72.00</td>
#       <td>251</td>
#       <td>NaN</td>
#       <td>2005.95</td>
#       <td>0.0000</td>
#       <td>0.3636</td>
#       <td>0.5484</td>
#       <td>0.8367</td>
#       <td>NaN</td>
#       <td>16.770</td>
#       <td>1.329898e+09</td>
#       <td>-2.429</td>
#       <td>NaN</td>
#       <td>4.293381</td>
#       <td>NaN</td>
#       <td>0.00000</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>BIOTEC</td>
#       <td>Biotec Pharmacon</td>
#       <td>Health care</td>
#       <td>9.18</td>
#       <td>9.16</td>
#       <td>9.28</td>
#       <td>83</td>
#       <td>NaN</td>
#       <td>443.71</td>
#       <td>0.0000</td>
#       <td>0.1769</td>
#       <td>0.7860</td>
#       <td>0.9326</td>
#       <td>1.0864</td>
#       <td>0.951</td>
#       <td>4.061067e+08</td>
#       <td>-0.130</td>
#       <td>-0.04</td>
#       <td>9.652997</td>
#       <td>0.276923</td>
#       <td>-0.07218</td>
#     </tr>
#     <tr>
#       <th>112</th>
#       <td>LSTSB-ME</td>
#       <td>Lillestrøm Sparebank</td>
#       <td>Equity certificates</td>
#       <td>130.00</td>
#       <td>126.00</td>
#       <td>134.00</td>
#       <td>0</td>
#       <td>LP</td>
#       <td>130.00</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0833</td>
#       <td>0.2548</td>
#       <td>877.957</td>
#       <td>2.766230e+09</td>
#       <td>90.434</td>
#       <td>NaN</td>
#       <td>0.148071</td>
#       <td>0.247384</td>
#       <td>0.49807</td>
#     </tr>
#     <tr>
#       <th>164</th>
#       <td>PLT</td>
#       <td>poLight</td>
#       <td>Information technology</td>
#       <td>68.50</td>
#       <td>68.50</td>
#       <td>69.00</td>
#       <td>48</td>
#       <td>LP</td>
#       <td>555.99</td>
#       <td>-0.0072</td>
#       <td>0.0148</td>
#       <td>0.6707</td>
#       <td>0.7474</td>
#       <td>1.2548</td>
#       <td>19.955</td>
#       <td>4.661645e+08</td>
#       <td>-7.262</td>
#       <td>NaN</td>
#       <td>3.432724</td>
#       <td>NaN</td>
#       <td>0.00000</td>
#     </tr>
#     <tr>
#       <th>171</th>
#       <td>REC</td>
#       <td>REC Silicon</td>
#       <td>Information technology</td>
#       <td>4.48</td>
#       <td>4.47</td>
#       <td>4.50</td>
#       <td>280</td>
#       <td>NaN</td>
#       <td>1253.59</td>
#       <td>0.0131</td>
#       <td>-0.1040</td>
#       <td>0.7112</td>
#       <td>0.6729</td>
#       <td>-0.2209</td>
#       <td>0.147</td>
#       <td>1.430863e+09</td>
#       <td>-0.335</td>
#       <td>0.00</td>
#       <td>30.476190</td>
#       <td>1.327125</td>
#       <td>-0.50536</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>BDRILL</td>
#       <td>Borr Drilling</td>
#       <td>Energy</td>
#       <td>44.73</td>
#       <td>44.80</td>
#       <td>44.97</td>
#       <td>183</td>
#       <td>NaN</td>
#       <td>4956.90</td>
#       <td>0.0052</td>
#       <td>-0.1301</td>
#       <td>-0.4213</td>
#       <td>-0.4096</td>
#       <td>-0.5780</td>
#       <td>12.188</td>
#       <td>6.402207e+09</td>
#       <td>-3.264</td>
#       <td>-0.14</td>
#       <td>3.689285</td>
#       <td>1.869828</td>
#       <td>-1.18018</td>
#     </tr>
#     <tr>
#       <th>204</th>
#       <td>MORG</td>
#       <td>Sparebanken Møre</td>
#       <td>Equity certificates</td>
#       <td>334.00</td>
#       <td>333.00</td>
#       <td>334.00</td>
#       <td>3</td>
#       <td>LP</td>
#       <td>3285.60</td>
#       <td>0.0121</td>
#       <td>0.0121</td>
#       <td>0.0503</td>
#       <td>0.0536</td>
#       <td>0.2342</td>
#       <td>706.774</td>
#       <td>3.102719e+10</td>
#       <td>34.500</td>
#       <td>30.98</td>
#       <td>0.472570</td>
#       <td>0.100404</td>
#       <td>0.45665</td>
#     </tr>
#     <tr>
#       <th>193</th>
#       <td>SOGN</td>
#       <td>Sogn Sparebank</td>
#       <td>Equity certificates</td>
#       <td>107.00</td>
#       <td>106.00</td>
#       <td>107.00</td>
#       <td>1</td>
#       <td>LP</td>
#       <td>67.68</td>
#       <td>0.0190</td>
#       <td>NaN</td>
#       <td>0.0000</td>
#       <td>0.0000</td>
#       <td>0.0396</td>
#       <td>1411.696</td>
#       <td>-7.429260e+08</td>
#       <td>7.366</td>
#       <td>NaN</td>
#       <td>0.075795</td>
#       <td>-0.083400</td>
#       <td>0.26904</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>CRAYON</td>
#       <td>Crayon Group Holding</td>
#       <td>Information technology</td>
#       <td>71.80</td>
#       <td>71.00</td>
#       <td>71.80</td>
#       <td>142</td>
#       <td>NaN</td>
#       <td>5491.40</td>
#       <td>0.0228</td>
#       <td>0.1770</td>
#       <td>0.3150</td>
#       <td>0.3808</td>
#       <td>3.0428</td>
#       <td>7.898</td>
#       <td>5.523998e+09</td>
#       <td>0.329</td>
#       <td>1.07</td>
#       <td>9.116232</td>
#       <td>1.403250</td>
#       <td>0.00208</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>ASETEK</td>
#       <td>Asetek</td>
#       <td>Information technology</td>
#       <td>39.50</td>
#       <td>39.00</td>
#       <td>39.50</td>
#       <td>43</td>
#       <td>NaN</td>
#       <td>977.90</td>
#       <td>-0.0113</td>
#       <td>0.3167</td>
#       <td>0.3621</td>
#       <td>0.2742</td>
#       <td>-0.1658</td>
#       <td>1.534</td>
#       <td>9.303980e+08</td>
#       <td>0.050</td>
#       <td>0.30</td>
#       <td>25.749674</td>
#       <td>0.276923</td>
#       <td>0.02390</td>
#     </tr>
#     <tr>
#       <th>234</th>
#       <td>VOW</td>
#       <td>Vow</td>
#       <td>Industrials</td>
#       <td>34.50</td>
#       <td>34.40</td>
#       <td>34.60</td>
#       <td>74</td>
#       <td>LP</td>
#       <td>3676.44</td>
#       <td>0.0058</td>
#       <td>0.0147</td>
#       <td>0.1538</td>
#       <td>0.1500</td>
#       <td>6.0259</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>EMGS</td>
#       <td>Electromagnetic Geoservices</td>
#       <td>Energy</td>
#       <td>2.23</td>
#       <td>2.25</td>
#       <td>2.26</td>
#       <td>182</td>
#       <td>NaN</td>
#       <td>292.06</td>
#       <td>0.1864</td>
#       <td>0.1680</td>
#       <td>0.0463</td>
#       <td>0.0813</td>
#       <td>0.6143</td>
#       <td>-0.016</td>
#       <td>2.917179e+08</td>
#       <td>-0.077</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2.174089</td>
#       <td>-0.15408</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>DNB</td>
#       <td>DNB</td>
#       <td>Financials</td>
#       <td>171.45</td>
#       <td>171.40</td>
#       <td>171.45</td>
#       <td>3649</td>
#       <td>NaN</td>
#       <td>269110.21</td>
#       <td>0.0455</td>
#       <td>0.0608</td>
#       <td>0.0379</td>
#       <td>0.0433</td>
#       <td>0.1727</td>
#       <td>145.608</td>
#       <td>9.818277e+11</td>
#       <td>16.074</td>
#       <td>14.88</td>
#       <td>1.178163</td>
#       <td>0.838056</td>
#       <td>0.48754</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>EQNR</td>
#       <td>Equinor</td>
#       <td>Energy</td>
#       <td>172.20</td>
#       <td>172.15</td>
#       <td>172.25</td>
#       <td>2489</td>
#       <td>NaN<

# %%
print_html(df_raw[df_raw.sector == 'Information technology'].sort_values(by='priceToBook').describe())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>last_</th>
#       <th>buy</th>
#       <th>sell</th>
#       <th>tradecount</th>
#       <th>marketcap</th>
#       <th>profit_today</th>
#       <th>profit_1wk</th>
#       <th>profit_1month</th>
#       <th>profit_ytd</th>
#       <th>profit_1yr</th>
#       <th>bookValue</th>
#       <th>enterpriseValue</th>
#       <th>trailingEps</th>
#       <th>forwardEps</th>
#       <th>priceToBook</th>
#       <th>beta</th>
#       <th>profitMargins</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>24.000000</td>
#       <td>24.000000</td>
#       <td>24.000000</td>
#       <td>24.000000</td>
#       <td>24.000000</td>
#       <td>21.000000</td>
#       <td>22.000000</td>
#       <td>24.000000</td>
#       <td>24.000000</td>
#       <td>22.000000</td>
#       <td>22.000000</td>
#       <td>2.300000e+01</td>
#       <td>22.000000</td>
#       <td>14.000000</td>
#       <td>21.000000</td>
#       <td>20.000000</td>
#       <td>23.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>50.265000</td>
#       <td>50.146667</td>
#       <td>50.489583</td>
#       <td>59.791667</td>
#       <td>3454.877500</td>
#       <td>-0.004329</td>
#       <td>0.023132</td>
#       <td>0.108304</td>
#       <td>0.115992</td>
#       <td>0.214677</td>
#       <td>6.587364</td>
#       <td>3.132391e+09</td>
#       <td>0.213818</td>
#       <td>1.590714</td>
#       <td>10.223667</td>
#       <td>0.984298</td>
#       <td>-0.212093</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>96.311039</td>
#       <td>96.386750</td>
#       <td>96.749928</td>
#       <td>99.216487</td>
#       <td>7697.096614</td>
#       <td>0.023332</td>
#       <td>0.092479</td>
#       <td>0.227494</td>
#       <td>0.261797</td>
#       <td>0.880834</td>
#       <td>8.141645</td>
#       <td>5.560076e+09</td>
#       <td>5.244460</td>
#       <td>4.413613</td>
#       <td>12.249917</td>
#       <td>0.997775</td>
#       <td>0.568049</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.210000</td>
#       <td>1.210000</td>
#       <td>1.220000</td>
#       <td>0.000000</td>
#       <td>42.880000</td>
#       <td>-0.067700</td>
#       <td>-0.104000</td>
#       <td>-0.128100</td>
#       <td>-0.121300</td>
#       <td>-0.869800</td>
#       <td>-0.402000</td>
#       <td>9.094161e+06</td>
#       <td>-9.214000</td>
#       <td>-6.100000</td>
#       <td>0.922509</td>
#       <td>-0.724279</td>
#       <td>-2.191890</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>4.225000</td>
#       <td>3.960000</td>
#       <td>4.195000</td>
#       <td>4.750000</td>
#       <td>346.077500</td>
#       <td>-0.007700</td>
#       <td>-0.022650</td>
#       <td>-0.026150</td>
#       <td>-0.050500</td>
#       <td>-0.207125</td>
#       <td>0.512250</td>
#       <td>3.048852e+08</td>
#       <td>-1.115500</td>
#       <td>0.020000</td>
#       <td>2.038284</td>
#       <td>0.294551</td>
#       <td>-0.032040</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>10.730000</td>
#       <td>10.710000</td>
#       <td>10.950000</td>
#       <td>9.500000</td>
#       <td>746.465000</td>
#       <td>0.000000</td>
#       <td>0.005950</td>
#       <td>0.021850</td>
#       <td>-0.001700</td>
#       <td>-0.017150</td>
#       <td>4.186000</td>
#       <td>8.645087e+08</td>
#       <td>-0.031500</td>
#       <td>0.630000</td>
#       <td>4.402956</td>
#       <td>0.861133</td>
#       <td>0.001180</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>50.787500</td>
#       <td>50.787500</td>
#       <td>50.887500</td>
#       <td>61.500000</td>
#       <td>2314.972500</td>
#       <td>0.008600</td>
#       <td>0.043550</td>
#       <td>0.155700</td>
#       <td>0.160500</td>
#       <td>0.650575</td>
#       <td>7.758250</td>
#       <td>3.152131e+09</td>
#       <td>0.649250</td>
#       <td>1.662500</td>
#       <td>14.831080</td>
#       <td>1.514988</td>
#       <td>0.051835</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>385.000000</td>
#       <td>385.000000</td>
#       <td>387.000000</td>
#       <td>382.000000</td>
#       <td>36327.480000</td>
#       <td>0.034000</td>
#       <td>0.316700</td>
#       <td>0.711200</td>
#       <td>0.747400</td>
#       <td>3.042800</td>
#       <td>25.959000</td>
#       <td>2.224025e+10</td>
#       <td>17.352000</td>
#       <td>13.840000</td>
#       <td>45.525290</td>
#       <td>2.850305</td>
#       <td>0.098180</td>
#     </tr>
#   </tbody>
# </table>

# %%
interval = alt.selection_interval(encodings=['x', 'y'])

chart = alt.Chart(df_altair_scored).mark_point().encode(
    color=alt.condition(interval, 'scores', alt.value('lightgray')),
    tooltip=['ticker'],
    size='mcap',
).properties(selection=interval)

(chart.encode(x='X_mds', y='Y_mds') | chart.encode(x='X_pca', y='Y_pca')) &\
(chart.encode(x='X_lle', y='Y_lle') | chart.encode(x='X_iso', y='Y_iso'))
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
